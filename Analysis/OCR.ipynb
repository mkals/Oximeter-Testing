# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
directory = 'Logs/'

try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
import cv2
import numpy as np
import easyocr
import png

reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
image_name = 'Logs/PO_20210507_1643/CA_Basler_632_20210507_164519.jpg'

image = cv2.imread(image_name,0)
#kernel = np.ones((10,10),np.uint8)
#image = cv2.erode(image,kernel,iterations = 1)
#plt.imshow(image)
#plt.colorbar()


#ret, image = cv2.threshold(image, 0, 255,cv2.THRESH_BINARY,cv2.THRESH_OTSU) #imgf contains Binary image
image = image[750:1350,500:3000]
#image = cv2.adaptiveThreshold(image,1,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2) #imgf contains Binary image

plt.figure()
plt.imshow(image)
plt.colorbar()

#processed_image = 'test.jpg'
#png.from_array(image, mode="L").save(processed_image)

#r1 = reader.readtext(image_name, paragraph=False, allowlist='0123456789', detail=0)
r2 = reader.readtext(image, paragraph=False, detail=0)
#r3 = reader.readtext(processed_image, paragraph=False, allowlist='0123456789', detail=0)
#print(r1)
print(r2)
#print(r3)

#print(pytesseract.image_to_string(image, config=' --psm 1 --oem 3  -c tessedit_char_whitelist=0123456789/'))

# List of available languages
#print(pytesseract.get_languages(config=''))
# Out:
# []
